# %% [markdown]
# # Clase de 11 de Octubre 2023

# %% [markdown]
# ## **---Gráficos---**

# %%
import matplotlib.pyplot as plt

# %%
tiempo = [0,1,2,3,4,5] # eje x
gusto = [0,10,100,80,85,90] # eje y

# %% [markdown]
# Asegurarse de que tengan el mismo largo, entonces se debe verificar.

# %%
len(tiempo)==len(gusto)
# Out:
# True

# %%
plt.plot(tiempo,gusto)

# %%
# plt.show()  #comando para usar en R

# %%
#plt.plot(gusto,tiempo)
#ptl.close 

#Para cerrar y abrir otro en R. Entonces 1. cerrar 2. graficar 3. mostrar

# %%
plt.plot(tiempo,gusto)
#Etiquetas
plt.xlabel('Tiempo (minutos)')
plt.ylabel('Gusto por producto')
# Out:
# Text(0, 0.5, 'Gusto por producto')

# %%
import pandas as pd
import os

# %%
pib_global =  pd.read_csv('gapminder_all.csv')
pib_global.head()
# Out:
#   continent       country  gdpPercap_1952  ...    pop_1997  pop_2002  pop_2007
# 0    Africa       Algeria     2449.008185  ...  29072015.0  31287142  33333216
# 1    Africa        Angola     3520.610273  ...   9875024.0  10866106  12420476
# 2    Africa         Benin     1062.752200  ...   6066080.0   7026113   8078314
# 3    Africa      Botswana      851.241141  ...   1536536.0   1630347   1639131
# 4    Africa  Burkina Faso      543.255241  ...  10352843.0  12251209  14326203
#
# [5 rows x 38 columns]

# %%
pib_ecuador = pib_global[pib_global.country == 'Ecuador']
pib_ecuador
# Out:
#    continent  country  gdpPercap_1952  ...    pop_1997  pop_2002  pop_2007
# 61  Americas  Ecuador     3522.110717  ...  11911819.0  12921234  13755680
#
# [1 rows x 38 columns]

# %%
pib_ecuador.iloc[0,1:3]#Esto puede cambiar si los datos cambian
# Out:
# country               Ecuador
# gdpPercap_1952    3522.110717
# Name: 61, dtype: object

# %% [markdown]
# Aqui esta imprimiendo OPCION 1

# %%
pib_ecuador.columns[pib_ecuador.columns.str.startswith('gdp')]# str.convierte tipo indice a tipo caracter
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
pib_ecuador.columns[pib_ecuador.columns.str.endswith('1962')]
# Out:
# Index(['gdpPercap_1962', 'lifeExp_1962', 'pop_1962'], dtype='object')

# %% [markdown]
# Aqui esta creando lista OPCION 2

# %%
col_int = []
for col in pib_ecuador.columns.values:
    if col.startswith('gdp'):
        col_int.append(col)

# %%
mi_lista = [col for col in pib_ecuador.columns.values if col.startswith('gdp')]
mi_lista
# Out:
# ['gdpPercap_1952',
#  'gdpPercap_1957',
#  'gdpPercap_1962',
#  'gdpPercap_1967',
#  'gdpPercap_1972',
#  'gdpPercap_1977',
#  'gdpPercap_1982',
#  'gdpPercap_1987',
#  'gdpPercap_1992',
#  'gdpPercap_1997',
#  'gdpPercap_2002',
#  'gdpPercap_2007']

# %%
pib_ecuador = pib_ecuador[mi_lista].T
pib_ecuador #61 es el índice de la columna
# Out:
#                          61
# gdpPercap_1952  3522.110717
# gdpPercap_1957  3780.546651
# gdpPercap_1962  4086.114078
# gdpPercap_1967  4579.074215
# gdpPercap_1972  5280.994710
# gdpPercap_1977  6679.623260
# gdpPercap_1982  7213.791267
# gdpPercap_1987  6481.776993
# gdpPercap_1992  7103.702595
# gdpPercap_1997  7429.455877
# gdpPercap_2002  5773.044512
# gdpPercap_2007  6873.262326

# %%
pib_ecuador.reset_index(inplace=True)
pib_ecuador.columns = ['anio','pib']
pib_ecuador
# Out:
#               anio          pib
# 0   gdpPercap_1952  3522.110717
# 1   gdpPercap_1957  3780.546651
# 2   gdpPercap_1962  4086.114078
# 3   gdpPercap_1967  4579.074215
# 4   gdpPercap_1972  5280.994710
# 5   gdpPercap_1977  6679.623260
# 6   gdpPercap_1982  7213.791267
# 7   gdpPercap_1987  6481.776993
# 8   gdpPercap_1992  7103.702595
# 9   gdpPercap_1997  7429.455877
# 10  gdpPercap_2002  5773.044512
# 11  gdpPercap_2007  6873.262326

# %% [markdown]
# Función Replace - Para que solo me extraiga los años

# %%
pib_ecuador['anio']= pib_ecuador['anio'].str.replace('gdpPercap_','')

# %%
pib_ecuador#Replace con nada y queda el año solo
# Out:
#     anio          pib
# 0   1952  3522.110717
# 1   1957  3780.546651
# 2   1962  4086.114078
# 3   1967  4579.074215
# 4   1972  5280.994710
# 5   1977  6679.623260
# 6   1982  7213.791267
# 7   1987  6481.776993
# 8   1992  7103.702595
# 9   1997  7429.455877
# 10  2002  5773.044512
# 11  2007  6873.262326

# %%
pib_ecuador['anio']= pib_ecuador.anio.astype(int)#asignar a los años como entero porque estaban como objeto
pib_ecuador
# Out:
#     anio          pib
# 0   1952  3522.110717
# 1   1957  3780.546651
# 2   1962  4086.114078
# 3   1967  4579.074215
# 4   1972  5280.994710
# 5   1977  6679.623260
# 6   1982  7213.791267
# 7   1987  6481.776993
# 8   1992  7103.702595
# 9   1997  7429.455877
# 10  2002  5773.044512
# 11  2007  6873.262326

# %%
pib_ecuador.dtypes #ahora año es entero y el pib son decimales
# Out:
# anio      int64
# pib     float64
# dtype: object

# %% [markdown]
# Con la información adecuada puedo hacer un gráfico

# %%
pib_ecuador.plot(x = 'anio', y= 'pib')
plt.xlabel('Año')
plt.ylabel('PIB per cápita')
# Out:
# Text(0, 0.5, 'PIB per cápita')

# %% [markdown]
# # Clase 12 de Octubre 2023

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pib_global =  pd.read_csv('gapminder_all.csv')
pib_global.head()
# Out:
#   continent       country  gdpPercap_1952  ...    pop_1997  pop_2002  pop_2007
# 0    Africa       Algeria     2449.008185  ...  29072015.0  31287142  33333216
# 1    Africa        Angola     3520.610273  ...   9875024.0  10866106  12420476
# 2    Africa         Benin     1062.752200  ...   6066080.0   7026113   8078314
# 3    Africa      Botswana      851.241141  ...   1536536.0   1630347   1639131
# 4    Africa  Burkina Faso      543.255241  ...  10352843.0  12251209  14326203
#
# [5 rows x 38 columns]

# %% [markdown]
# Comparamos el PIB de Ecuador y Chile

# %%
pib_ecuador = pib_global[(pib_global.country == 'Ecuador')|(pib_global.country == 'Chile')]
pib_ecuador
# Out:
#    continent  country  gdpPercap_1952  ...    pop_1997  pop_2002  pop_2007
# 56  Americas    Chile     3939.978789  ...  14599929.0  15497046  16284741
# 61  Americas  Ecuador     3522.110717  ...  11911819.0  12921234  13755680
#
# [2 rows x 38 columns]

# %%
pib_ecuador.columns[pib_ecuador.columns.str.startswith('gdp')]
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %% [markdown]
# Para obtener el mismo resultado:

# %%
col_int=[]
for col in pib_ecuador.columns.values: #values me da como un array,columnas llamadas col
    if col.startswith('gdp'):# haciendo este buckle con array ya se hace str
        col_int.append(col)# en la col vacía llena

# %% [markdown]
# Ahora lo mismo le hago lista:

# %%
mi_lista = [col for col in pib_ecuador.columns.values if col.startswith('gdp')]
mi_lista
# Out:
# ['gdpPercap_1952',
#  'gdpPercap_1957',
#  'gdpPercap_1962',
#  'gdpPercap_1967',
#  'gdpPercap_1972',
#  'gdpPercap_1977',
#  'gdpPercap_1982',
#  'gdpPercap_1987',
#  'gdpPercap_1992',
#  'gdpPercap_1997',
#  'gdpPercap_2002',
#  'gdpPercap_2007']

# %%
nombres_pais = pd.DataFrame(pib_ecuador.country)
nombres_pais
# Out:
#     country
# 56    Chile
# 61  Ecuador

# %%
pib_ecuador = pib_ecuador[mi_lista].T
pib_ecuador #61 es el índice de la columna
# Out:
#                           56           61
# gdpPercap_1952   3939.978789  3522.110717
# gdpPercap_1957   4315.622723  3780.546651
# gdpPercap_1962   4519.094331  4086.114078
# gdpPercap_1967   5106.654313  4579.074215
# gdpPercap_1972   5494.024437  5280.994710
# gdpPercap_1977   4756.763836  6679.623260
# gdpPercap_1982   5095.665738  7213.791267
# gdpPercap_1987   5547.063754  6481.776993
# gdpPercap_1992   7596.125964  7103.702595
# gdpPercap_1997  10118.053180  7429.455877
# gdpPercap_2002  10778.783850  5773.044512
# gdpPercap_2007  13171.638850  6873.262326

# %%
pib_ecuador.columns = nombres_pais.country
pib_ecuador
# Out:
# country                Chile      Ecuador
# gdpPercap_1952   3939.978789  3522.110717
# gdpPercap_1957   4315.622723  3780.546651
# gdpPercap_1962   4519.094331  4086.114078
# gdpPercap_1967   5106.654313  4579.074215
# gdpPercap_1972   5494.024437  5280.994710
# gdpPercap_1977   4756.763836  6679.623260
# gdpPercap_1982   5095.665738  7213.791267
# gdpPercap_1987   5547.063754  6481.776993
# gdpPercap_1992   7596.125964  7103.702595
# gdpPercap_1997  10118.053180  7429.455877
# gdpPercap_2002  10778.783850  5773.044512
# gdpPercap_2007  13171.638850  6873.262326

# %%
pib_ecuador.index
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
pib_ecuador.reset_index(inplace = True)

# %%
pib_ecuador.rename(columns = {'index':'anio'}, inplace = True) #inplace = True para que gruarde la info en el mismo DataFrame pib_ecuador 
pib_ecuador
# Out:
# country            anio         Chile      Ecuador
# 0        gdpPercap_1952   3939.978789  3522.110717
# 1        gdpPercap_1957   4315.622723  3780.546651
# 2        gdpPercap_1962   4519.094331  4086.114078
# 3        gdpPercap_1967   5106.654313  4579.074215
# 4        gdpPercap_1972   5494.024437  5280.994710
# 5        gdpPercap_1977   4756.763836  6679.623260
# 6        gdpPercap_1982   5095.665738  7213.791267
# 7        gdpPercap_1987   5547.063754  6481.776993
# 8        gdpPercap_1992   7596.125964  7103.702595
# 9        gdpPercap_1997  10118.053180  7429.455877
# 10       gdpPercap_2002  10778.783850  5773.044512
# 11       gdpPercap_2007  13171.638850  6873.262326

# %%
pib_ecuador['anio']= pib_ecuador['anio'].str.replace('gdpPercap_','')
pib_ecuador #Ya me sale solo el año
# Out:
# country  anio         Chile      Ecuador
# 0        1952   3939.978789  3522.110717
# 1        1957   4315.622723  3780.546651
# 2        1962   4519.094331  4086.114078
# 3        1967   5106.654313  4579.074215
# 4        1972   5494.024437  5280.994710
# 5        1977   4756.763836  6679.623260
# 6        1982   5095.665738  7213.791267
# 7        1987   5547.063754  6481.776993
# 8        1992   7596.125964  7103.702595
# 9        1997  10118.053180  7429.455877
# 10       2002  10778.783850  5773.044512
# 11       2007  13171.638850  6873.262326

# %%
pib_ecuador['anio'] = pib_ecuador.anio.astype(int) 

# convirtiendo el año de str a entero

# %%
pib_ecuador.dtypes
# Out:
# country
# anio         int64
# Chile      float64
# Ecuador    float64
# dtype: object

# %%
pib_ecuador.plot(x = 'anio', y= 'Chile')
plt.xlabel('Año')#asume las etiquetas solo ara el ultimo gráfico
plt.ylabel('PIB per cápita')
pib_ecuador.plot(x = 'anio', y= 'Ecuador')
plt.xlabel('Año')#asume las etiquetas solo ara el ultimo gráfico
plt.ylabel('PIB per cápita')
# Out:
# Text(0, 0.5, 'PIB per cápita')

# %%
fig = plt.figure()#un gráfico dentro de la figura 
eje = fig.add_subplot(1,1,1) #n filas #n columnas #indice 46:26
pib_ecuador.plot(x = 'anio', y= 'Chile',ax = eje, linestyle = '-.')
pib_ecuador.plot(x = 'anio', y= 'Ecuador',ax = eje, linestyle = '--')
plt.xlabel('Año')#asume las etiquetas solo ara el ultimo gráfico
plt.ylabel('PIB per cápita')
# Out:
# Text(0, 0.5, 'PIB per cápita')

# %%
fig= plt.figure()
eje = fig.add_subplot(1,2,1)
pib_ecuador.plot(x= 'anio', y = 'Chile', ax= eje, ls = '-.')

eje2 = fig.add_subplot(1,2,2,sharey = eje)
pib_ecuador.plot(x = 'anio', y = 'Ecuador', ax = eje2, ls = 'dotted')
eje.set_xlabel('Año')
eje2.set_xlabel('Año')

# mas opciones en matplotlib
# Out:
# Text(0.5, 0, 'Año')
